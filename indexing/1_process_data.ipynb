# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import json
import re
import nltk
import math
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from collections import Counter,defaultdict
import pickle
from itertools import chain
from bs4 import BeautifulSoup

# DEFS ----------------------------------------------------------------------------------------------------
def load_data(file):
    
    with open(file) as f:
        json_block = []
        for line in f:
            json_block.append(json.loads(line))
            
    return pd.DataFrame(json_block)

def tokenize(text):
    return [re.sub(r'[^\w\s]','',w) for w in nltk.word_tokenize(text.lower()) if re.sub(r'[^\w\s]','',w) != '']
   
def remove_stopwords(tokens):
    en_stopwords = set(stopwords.words('english'))
    return [word for word in tokens if word not in en_stopwords]

def stemmer(tokens):
    stemmer = SnowballStemmer("english")
    return [stemmer.stem(token) for token in tokens]

def process_filmography(filmography_object):
    filmography = []
    for item in filmography_object:
        movie_instance = {}
        soup = BeautifulSoup(item, 'html.parser')
        movie_instance['url'] = 'https://www.imdb.com' + soup.b.a.get('href')
        movie_instance['title'] = soup.b.a.get_text()
        movie_instance['data'] = ' '.join(soup.get_text().strip().replace('\n',' ').split(' '))
        filmography.append(movie_instance)
    
    return filmography
    
def retrieve_relative_news_collection(name):
    selection = news[news['content'].str.contains(name)]
    
    #result = {}
    #result['urls'] = selection.url.values
    
    tokens = []
    for l in selection.tokenized:
        tokens += l
    
    #result['text'] = tokens
    return tokens

def retrieve_relative_movies_collection(filmography):
    list_movies = [movie["title"] for movie in filmography][:3]
    
    selection = movies[movies["title"].isin(list_movies)]
    
    #result = {}
    #result['urls'] = selection.url_imdb.values
    #result['genres'] = [genre for genres in selection.genres.values for genre in genres]
    
    tokens = []
    for l in selection.tokenized:
        tokens += l
    
    #result['text'] = tokens
    return tokens

def create_inv_indexes(df):
    invertedIndexFreq = defaultdict(Counter)
    invertedIndexPos = defaultdict(dict)
    corpusInfo = defaultdict(dict)
    
    corpusInfo['num_docs'] = df.shape[0]
    
    for index, row in df.iterrows():
        corpusInfo['doc_lengths'][row['name']] = len(row['tokenized'])
        
        for w in row['tokenized']:
            invertedIndexFreq[w][row['name']]+=1
            invertedIndexPos[w][row['name']] = [i for i, j in enumerate(row['tokenized']) if w == j]
            
    return invertedIndexFreq, invertedIndexPos, corpusInfo

def tfidf(doc_freq, doc_length, n_docs_total, n_docs_containing):
    return (doc_freq / doc_length) * math.log(n_docs_total / (1 + n_docs_containing))

# %%
# LOAD ----------------------------------------------------------------------------------------------------
actors_jl = '../data/actors.jl'
movies_jl = '../data/movies.jl'
tmz_jl = '../data/news_tmz.jl'
hollywoodlife_jl = '../data/news_hollywoodlife.jl'
movieweb_jl = '../data/news_movieweb.jl'

actors = load_data(actors_jl)
movies = load_data(movies_jl)
tmz = load_data(tmz_jl)
hollywoodlife = load_data(hollywoodlife_jl)
movieweb = load_data(movieweb_jl)

# %%
# PREPROCESS -----------------------------------------------------------------------------------------------
actors['filmography'] = actors.apply(lambda row: process_filmography(row.filmography), axis=1)

# %%
#actors['movie_urls'] = actors.apply(lambda row: ['https://www.imdb.com' + url for url in row.movie_urls], axis=1)

# %%
movies['tokenized'] = movies.apply(lambda row: stemmer(remove_stopwords(tokenize(row.title + ' ' + row.year + ' ' + ' '.join(row.genres) + ' ' + ' '.join(row.reviews)))), axis=1)

# %%
tmz['tokenized'] = tmz.apply(lambda row: stemmer(remove_stopwords(tokenize(row.title + ' ' + row.content))), axis=1)

# %%
hollywoodlife['tokenized'] = hollywoodlife.apply(lambda row: stemmer(remove_stopwords(tokenize(row.title + ' ' + row.content))), axis=1)

# %%
movieweb['tokenized'] = movieweb.apply(lambda row: stemmer(remove_stopwords(tokenize(row.title + ' ' + row.content))), axis=1)

# %%
news = tmz.append(hollywoodlife)
news = news.append(movieweb)

# %%
actors.head()
# Out:
#                                             bio_imdb  \
# 0  Harrison Ford was born on July 13, 1942 in Chi...
# 1  Eric Bana was born Eric Banadinovic on August ...
# 2  At a consistently lean 6' 2", green-eyed Timot...
# 3  Catherine Zeta-Jones was born September 25, 19...
# 4  Kit Harington was born Christopher Catesby Har...
#
#                                           bio_rottom       birthday  \
# 0  If Harrison Ford had listened to the advice of...   Jul 13, 1942
# 1  A popular and easygoing Australian comedian wh...    Aug 9, 1968
# 2  British actor Timothy Dalton has excelled in r...   Mar 21, 1944
# 3  Both exotic and classic, Wales-born actress Ca...   Sep 25, 1969
# 4  Descended from a viscount who served as Britai...  Not Available
#
#                        birthplace  \
# 0               Chicago, Illinois
# 1  Melbourne, Victoria, Australia
# 2           Colwyn Bay, Wales, UK
# 3  Swansea, West Glamorgan, Wales
# 4                   Not Available
#
#                                          filmography  \
# 0  [{u'url': u'https://www.imdb.com/title/tt14627...
# 1  [{u'url': u'https://www.imdb.com/title/tt51441...
# 2  [{u'url': u'https://www.imdb.com/title/tt19793...
# 3  [{u'url': u'https://www.imdb.com/title/tt83968...
# 4  [{u'url': u'https://www.imdb.com/title/tt23864...
#
#                                           movie_urls                  name  \
# 0  [/title/tt1462764/?ref_=nm_flmg_act_1, /title/...         Harrison Ford
# 1  [/title/tt5144174/?ref_=nm_flmg_act_1, /title/...             Eric Bana
# 2  [/title/tt1979376/?ref_=nm_flmg_act_1, /title/...        Timothy Dalton
# 3  [/title/tt8396890/?ref_=nm_flmg_act_1, /title/...  Catherine Zeta-Jones
# 4  [/title/tt2386490/?ref_=nm_flmg_act_1, /title/...         Kit Harington
#
#                                  quotes_brainyquotes  \
# 0  [Nature doesn't need people - people need natu...
# 1  [I look my best when I take my helmet off afte...
# 2  [You can't relate to a superhero, to a superma...
# 3  [Being glamorous is about strength and confide...
# 4  [I'm very lucky, I've got two very loving pare...
#
#                                          quotes_imdb  \
# 0  [It's a little-known fact, but I wanted Han So...
# 1  [I wanted to be a mechanic. When I was 14, I w...
# 2  [On playing a character: You can't relate to a...
# 3  [I used to go around looking as frumpy as poss...
# 4  [I wear quite fitted clothing. I don't like we...
#
#                                        quotes_rottom  \
# 0  [Jack Stanfield Leave my family alone! Get off...
# 1  [Dr. David Banner Sleep  now,  Bruce,  and  fo...
# 2  [Jenny Blake Oh my God. Neville Sinclair's a.....
# 3  [Chloe Are you telling a woman with pan full o...
# 4  [Will Holloway If there's something else I hav...
#
#                                url_imdb  \
# 0  https://www.imdb.com/name/nm0000148/
# 1  https://www.imdb.com/name/nm0051509/
# 2  https://www.imdb.com/name/nm0001096/
# 3  https://www.imdb.com/name/nm0001876/
# 4  https://www.imdb.com/name/nm3229685/
#
#                                              url_img  \
# 0  https://m.media-amazon.com/images/M/MV5BMTY4Mj...
# 1  https://m.media-amazon.com/images/M/MV5BMjcxMz...
# 2  https://m.media-amazon.com/images/M/MV5BNDE5ND...
# 3  https://m.media-amazon.com/images/M/MV5BZGE4Mz...
# 4  https://m.media-amazon.com/images/M/MV5BMTA2NT...
#
#                                           url_rottom
# 0  https://www.rottentomatoes.com/celebrity/harri...
# 1  https://www.rottentomatoes.com/celebrity/eric_...
# 2  https://www.rottentomatoes.com/celebrity/timot...
# 3  https://www.rottentomatoes.com/celebrity/cathe...
# 4  https://www.rottentomatoes.com/celebrity/kit_h...

# %%
# MATCH ------------------------------------------------------------------------------------------------------
actors_movies = actors[['name','filmography']]
actors_movies['tokenized'] = actors.apply(lambda row: retrieve_relative_movies_collection(row["filmography"]), axis=1)
actors_movies = actors_movies.drop(columns=['filmography'])

# %%
actors_news = actors[['name']]
actors_news['tokenized'] = actors.apply(lambda row: retrieve_relative_news_collection(row["name"]), axis=1)

# %%
# TOKENIZE ACTOR -----------------------------------------------------------------------------------------------
actors['tokenized'] = actors.apply(lambda row: stemmer(remove_stopwords(tokenize(row["bio_imdb"] 
                                            + ' ' + row["bio_rottom"] + ' ' + row["birthday"] 
                                            + ' ' + row["birthplace"] + ' ' + row["name"]
                                            + ' ' + ' '.join(row["quotes_brainyquotes"])
                                            + ' ' + ' '.join(row["quotes_imdb"])
                                            + ' ' + ' '.join(row["quotes_rottom"])))), axis=1)

# %%
# INDEX ------------------------------------------------------------------------------------------------------
# MAIN
main_indexes = create_inv_indexes(actors)
main_ii_freq = main_indexes[0]
main_ii_pos = main_indexes[1]
main_corpus_info = main_indexes[2]

# %%
# MOVIES
movies_indexes = create_inv_indexes(actors_movies)
movies_ii_freq = movies_indexes[0]
movies_ii_pos = movies_indexes[1]
movies_corpus_info = movies_indexes[2]

# %%
# NEWS
news_indexes = create_inv_indexes(actors_news)
news_ii_freq = news_indexes[0]
news_ii_pos = news_indexes[1]
news_corpus_info = news_indexes[2]

# %%
# MERGING
# Merging frequencies
merged_ii_freq = defaultdict(Counter)
for k,v in chain(main_ii_freq.items(), movies_ii_freq.items(), 
                 news_ii_freq.items()):
    
    merged_ii_freq[k].update(v)

# %%
with open('../data/ii_freq.pickle', 'wb') as handle:
    pickle.dump(merged_ii_freq, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Merging positional
merged_ii_pos = main_ii_pos

# Merge indexes
for w, dic in movies_ii_pos.items():
    for doc, lis in dic.items():
        merged_ii_pos[w][doc] = lis
        
for w, dic in news_ii_pos.items():
    for doc, lis in dic.items():
        merged_ii_pos[w][doc] = lis

# %%
with open('../data/ii_pos.pickle', 'wb') as handle:
    pickle.dump(merged_ii_pos, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Merging corpus infos
merged_ci = main_corpus_info

merged_ci['num_docs'] += movies_corpus_info['num_docs'] 
for doc, length in movies_corpus_info['doc_lengths'].items():
    merged_ci['doc_lengths'][doc] = length
      
merged_ci['num_docs'] += news_corpus_info['num_docs'] 
for doc, length in news_corpus_info['doc_lengths'].items():
    merged_ci['doc_lengths'][doc] = length

# %%
# WEIGHTS
merged_ii_weights = defaultdict(Counter)

for w,wv in merged_ii_freq.items():
    n_docs_total = merged_ci['num_docs']
    n_docs_containing = len(wv)
    
    for d_id,dv in wv.items():
        doc_freq = dv
        doc_length = merged_ci['doc_lengths'][d_id]
        
        merged_ii_weights[w][d_id] = tfidf(doc_freq, doc_length, n_docs_total, n_docs_containing)

# %%
with open('../data/ii_weights.pickle', 'wb') as handle:
    pickle.dump(merged_ii_weights, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# EXPORT ------------------------------------------------------------------------------------------------------

# %%
# DATAFRAMES
with open('../data/actors.pickle', 'wb') as handle:
    pickle.dump(actors, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('../data/movies.pickle', 'wb') as handle:
    pickle.dump(movies, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('../data/news.pickle', 'wb') as handle:
    pickle.dump(news, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# TEST ------------------------------------------------------------------------------------------------------
merged_ii_weights['action']
# Out:
# Counter({u'50 Cent': 0.0,
#          u'Aaliyah': 0.0,
#          u'Aamir Khan': 2.5649493574615367,
#          u'Aaron Eckhart': 2.5649493574615367,
#          u'Aaron Sorkin': 2.5649493574615367,
#          u'Abbie Cornish': 2.5649493574615367,
#          u'Adam Baldwin': 2.5649493574615367,
#          u'Adam Beach': 0.0,
#          u'Adam Brody': 2.5649493574615367,
#          u'Adam Lambert': 0.0,
#          u'Adam Scott': 2.5649493574615367,
#          u'Adewale Akinnuoye-Agbaje': 0.0,
#          u'Adrianne Palicki': 0.0,
#          u'Agnes Bruckner': 0.0,
#          u'Aidan Gillen': 2.5649493574615367,
#          u'Aishwarya Rai Bachchan': 0.0,
#          u'Akira Kurosawa': 5.1298987149230735,
#          u'Alan Arkin': 2.5649493574615367,
#          u'Alan Cumming': 2.5649493574615367,
#          u'Alan Tudyk': 0.0,
#          u'Albert Brooks': 0.0,
#          u'Alec Baldwin': 5.1298987149230735,
#          u'Alex Pettyfer': 0.0,
#          u'Alexandra Paul': 0.0,
#          u'Alexis Bledel': 0.0,
#          u'Alexis Denisof': 0.0,
#          u'Ally Walker': 0.0,
#          u'Amy Adams': 0.0,
#          u'Amy Jackson': 5.1298987149230735,
#          u'Amy Poehler': 0.0,
#          u'Amy Ryan': 0.0,
#          u'Amy Smart': 2.5649493574615367,
#          u'Andre Braugher': 2.5649493574615367,
#          u'Andrea Riseborough': 0.0,
#          u'Andrea Roth': 0.0,
#          u'Andrew Garfield': 0.0,
#          u'Andrew Keegan': 0.0,
#          u'Andrew Lincoln': 0.0,
#          u'Andy Garcia': 0.0,
#          u'Andy Serkis': 0.0,
#          u'Ang Lee': 2.5649493574615367,
#          u'Angela Bassett': 5.1298987149230735,
#          u'Angelina Jolie': 5.1298987149230735,
#          u'Angie Harmon': 0.0,
#          u'Anna Nicole Smith': 0.0,
#          u'Anna Popplewell': 2.5649493574615367,
#          u'Anne Hathaway': 0.0,
#          u'Anne Parillaud': 0.0,
#          u'Annette Bening': 0.0,
#          u'Annie Ilonzeh': 0.0,
#          u'Ansel Elgort': 2.5649493574615367,
#          u'Anthony Daniels': 0.0,
#          u'Anthony Edwards': 0.0,
#          u'Anthony Mackie': 0.0,
#          u'Anthony Quinn': 0.0,
#          u'Antoine Fuqua': 10.259797429846147,
#          u'Antonio Banderas': 0.0,
#          u'Antony Starr': 2.5649493574615367,
#          u'Anushka Sharma': 0.0,
#          u'Armand Assante': 2.5649493574615367,
#          u'Armie Hammer': 7.694848072384611,
#          u'Arnold Schwarzenegger': 35.909291004461515,
#          u'Ashley Scott': 5.1298987149230735,
#          u'Ashton Holmes': 0.0,
#          u'Ashton Kutcher': 0.0,
#          u'Asia Argento': 2.5649493574615367,
#          u'Audrey Hepburn': 0.0,
#          u'Austin Butler': 0.0,
#          u'Bai Ling': 0.0,
#          u'Barry Bostwick': 0.0,
#          u'Barry Pepper': 0.0,
#          u'Ben Affleck': 5.1298987149230735,
#          u'Ben Barnes': 0.0,
#          u'Ben Mendelsohn': 0.0,
#          u'Benedict Wong': 2.5649493574615367,
#          u'Benjamin Bratt': 0.0,
#          u'Beth Broderick': 0.0,
#          u'Bette Davis': 0.0,
#          u'Betty Gilpin': 0.0,
#          u'Bill Murray': 0.0,
#          u'Bill Nighy': 0.0,
#          u'Billie Lourd': 2.5649493574615367,
#          u'Billy Crudup': 0.0,
#          u'Bokeem Woodbine': 0.0,
#          u'Bonnie Bedelia': 2.5649493574615367,
#          u'Booboo Stewart': 2.5649493574615367,
#          u'Brad Bird': 0.0,
#          u'Brad Pitt': 2.5649493574615367,
#          u'Bradley Cooper': 0.0,
#          u'Bradley Whitford': 0.0,
#          u'Brandon Lee': 2.5649493574615367,
#          u'Brendan Gleeson': 2.5649493574615367,
#          u'Brent Spiner': 0.0,
#          u'Brian Cox': 0.0,
#          u'Brian De Palma': 2.5649493574615367,
#          u'Brian Dennehy': 2.5649493574615367,
#          u'Brian Tee': 2.5649493574615367,
#          u'Bridget Moynahan': 0.0,
#          u'Bridgit Mendler': 2.5649493574615367,
#          u'Brie Larson': 0.0,
#          u'Brion James': 0.0,
#          u'Britt Ekland': 0.0,
#          u'Brittany Murphy': 0.0,
#          u'Brooke Smith': 0.0,
#          u'Bruce Greenwood': 0.0,
#          u'Bruce Lee': 2.5649493574615367,
#          u'Bruce Willis': 10.259797429846147,
#          u'Bryan Cranston': 0.0,
#          u'Bryan Singer': 0.0,
#          u'Burn Gorman': 0.0,
#          u'Burt Reynolds': 0.0,
#          u'Buster Keaton': 2.5649493574615367,
#          u'Caity Lotz': 2.5649493574615367,
#          u'Caleb Landry Jones': 5.1298987149230735,
#          u'Callan McAuliffe': 0.0,
#          u'Cameron Diaz': 0.0,
#          u'Cameron Monaghan': 0.0,
#          u'Camilla Belle': 0.0,
#          u'Cara Delevingne': 5.1298987149230735,
#          u'Carey Mulligan': 5.1298987149230735,
#          u'Carl Weathers': 7.694848072384611,
#          u'Carmen Ejogo': 0.0,
#          u'Carrie-Anne Moss': 5.1298987149230735,
#          u'Cary Elwes': 0.0,
#          u'Cary-Hiroyuki Tagawa': 0.0,
#          u'Casper Van Dien': 2.5649493574615367,
#          u'Cassi Thomson': 0.0,
#          u'Cate Blanchett': 0.0,
#          u'Catherine Bell': 0.0,
#          u'Catherine Deneuve': 2.5649493574615367,
#          u'Catherine McCormack': 0.0,
#          u'Celina Jade': 0.0,
#          u'Chandra Wilson': 0.0,
#          u'Channing Tatum': 2.5649493574615367,
#          u'Charles Bronson': 5.1298987149230735,
#          u'Charles Dance': 2.5649493574615367,
#          u'Charlie Sheen': 2.5649493574615367,
#          u'Charlize Theron': 0.0,
#          u'Charlton Heston': 2.5649493574615367,
#          u'Cheryl Ladd': 0.0,
#          u'Cheyenne Jackson': 0.0,
#          u'Chi McBride': 2.5649493574615367,
#          u'Chiaki Kuriyama': 0.0,
#          u'Chiwetel Ejiofor': 0.0,
#          u'Chris Klein': 2.5649493574615367,
#          u'Chris Noth': 0.0,
#          u'Chris Tucker': 2.5649493574615367,
#          u'Christian Kane': 0.0,
#          u'Christian Slater': 2.5649493574615367,
#          u'Christina Applegate': 0.0,
#          u'Christine Lahti': 0.0,
#          u'Christopher Judge': 0.0,
#          u'Christopher Lambert': 5.1298987149230735,
#          u'Christopher McQuarrie': 5.1298987149230735,
#          u'Christopher Nolan': 10.259797429846147,
#          u'Christopher Walken': 2.5649493574615367,
#          u'Christy Carlson Romano': 0.0,
#          u'Chuck Norris': 10.259797429846147,
#          u'Claire Holt': 2.5649493574615367,
#          u'Clancy Brown': 2.5649493574615367,
#          u'Clark Gable': 0.0,
#          u'Clifton Collins Jr.': 0.0,
#          u'Clint Eastwood': 2.5649493574615367,
#          u'Clive Owen': 0.0,
#          u'Cobie Smulders': 0.0,
#          u'Cole Hauser': 5.1298987149230735,
#          u'Cole Sprouse': 0.0,
#          u'Colin Farrell': 2.5649493574615367,
#          u'Common': 0.0,
#          u'Conan Stevens': 0.0,
#          u'Connie Nielsen': 0.0,
#          u'Corbin Bleu': 0.0,
#          u'Corey Haim': 2.5649493574615367,
#          u'Corey Stoll': 0.0,
#          u'Courtney Eaton': 0.0,
#          u'Crispin Glover': 0.0,
#          u'Daisy Ridley': 0.0,
#          u'Dakota Blue Richards': 0.0,
#          u'Dakota Goyo': 0.0,
#          u'Dallas Roberts': 2.5649493574615367,
#          u'Damon Wayans': 0.0,
#          u'Dan Stevens': 0.0,
#          u'Danai Gurira': 0.0,
#          u'Daniel Craig': 0.0,
#          u'Daniel Dae Kim': 0.0,
#          u'Daniel Kaluuya': 5.1298987149230735,
#          u'Daniel Radcliffe': 0.0,
#          u'Daniel Wu': 2.5649493574615367,
#          u'Danny Boyle': 0.0,
#          u'Danny Strong': 0.0,
#          u'Danny Trejo': 2.5649493574615367,
#          u'Daphne Zuniga': 0.0,
#          u'Darren Aronofsky': 0.0,
#          u'Daryl Hannah': 0.0,
#          u'Daryl Sabara': 0.0,
#          u'Dash Mihok': 0.0,
#          u'Dave Bautista': 2.5649493574615367,
#          u'David Arquette': 0.0,
#          u'David Ayer': 0.0,
#          u'David Carradine': 0.0,
#          u'David Costabile': 0.0,
#          u'David Dastmalchian': 2.5649493574615367,
#          u'David Fincher': 0.0,
#          u'David Hasselhoff': 0.0,
#          u'David Hemmings': 0.0,
#          u'David Koechner': 0.0,
#          u'David Leitch': 5.1298987149230735,
#          u'David Oyelowo': 0.0,
#          u'David Thewlis': 2.5649493574615367,
#          u'David Wenham': 5.1298987149230735,
#          u'Dax Shepard': 0.0,
#          u'Dean Cain': 2.5649493574615367,
#          u'Debby Ryan': 5.1298987149230735,
#          u'Debra Paget': 0.0,
#          u'Debra Winger': 0.0,
#          u'Delroy Lindo': 0.0,
#          u'Denis Villeneuve': 2.5649493574615367,
#          u'Denise Richards': 0.0,
#          u'Dennis Haysbert': 0.0,
#          u'Denzel Washington': 5.1298987149230735,
#          u'Devon Bostick': 0.0,
#          u'Devon Sawa': 5.1298987149230735,
#          u'Diane Keaton': 0.0,
#          u'Dianna Agron': 0.0,
#          u'Dirk Benedict': 0.0,
#          u'Djimon Hounsou': 0.0,
#          u'Dolph Lundgren': 15.389696144769221,
#          u'Dom DeLuise': 0.0,
#          u'Donna Murphy': 0.0,
#          u'Donnie Wahlberg': 2.5649493574615367,
#          u'Donnie Yen': 71.81858200892303,
#          u'Drew Barrymore': 0.0,
#          u'Dwayne Johnson': 2.5649493574615367,
#          u'Dwight Yoakam': 2.5649493574615367,
#          u'Dyan Cannon': 0.0,
#          u'Ed Skrein': 5.1298987149230735,
#          u'Eddie Marsan': 0.0,
#          u'Edgar Wright': 2.5649493574615367,
#          u'Edward Albert': 0.0,
#          u'Edward Burns': 0.0,
#          u'Edward Herrmann': 0.0,
#          u'Edward James Olmos': 0.0,
#          u'Elena Anaya': 2.5649493574615367,
#          u'Elisha Cuthbert': 0.0,
#          u'Elizabeth Banks': 0.0,
#          u'Elizabeth Hurley': 0.0,
#          u'Ellen Page': 0.0,
#          u'Emeraude Toubia': 0.0,
#          u'Emilia Clarke': 0.0,
#          u'Emily Browning': 0.0,
#          u'Emily Deschanel': 0.0,
#          u'Emma Watson': 0.0,
#          u'Emmanuel Lubezki': 2.5649493574615367,
#          u'Emmanuelle Seigner': 0.0,
#          u'Enrico Colantoni': 0.0,
#          u'Eric Dane': 2.5649493574615367,
#          u'Eric Mabius': 2.5649493574615367,
#          u'Erika Eleniak': 2.5649493574615367,
#          u'Erin Moriarty': 2.5649493574615367,
#          u'Ernest Borgnine': 2.5649493574615367,
#          u'Ernie Hudson': 2.5649493574615367,
#          u'Errol Flynn': 0.0,
#          u'Eva Green': 0.0,
#          u'Ewan McGregor': 0.0,
#          u'Ezra Miller': 0.0,
#          u'F. Murray Abraham': 2.5649493574615367,
#          u'Famke Janssen': 0.0,
#          u'Finn Wittrock': 2.5649493574615367,
#          u'Fionn Whitehead': 2.5649493574615367,
#          u'Francis Ford Coppola': 0.0,
#          u'Frank Darabont': 0.0,
#          u'Frank Oz': 0.0,
#          u'Franka Potente': 0.0,
#          u'Fred Ward': 0.0,
#          u'Gabourey Sidibe': 0.0,
#          u'Gabriel Macht': 2.5649493574615367,
#          u'Gabrielle Union': 2.5649493574615367,
#          u'Gary Oldman': 0.0,
#          u'Geena Davis': 2.5649493574615367,
#          u'Gemma Arterton': 0.0,
#          u'Gene Hackman': 5.1298987149230735,
#          u'George Eads': 2.5649493574615367,
#          u'George Kennedy': 0.0,
#          u'George Lazenby': 0.0,
#          u'George Lucas': 0.0,
#          u'George Miller': 2.5649493574615367,
#          u'George Peppard': 0.0,
#          u'Gerard Way': 2.5649493574615367,
#          u'Giancarlo Esposito': 2.5649493574615367,
#          u'Gillian Anderson': 0.0,
#          u'Gina Carano': 10.259797429846147,
#          u'Gina Gershon': 0.0,
#          u'Gina Torres': 0.0,
#          u'Ginger Rogers': 2.5649493574615367,
#          u'Giovanni Ribisi': 2.5649493574615367,
#          u'Glenda Jackson': 0.0,
#          u'Grace Jones': 0.0,
#          u'Grace Park': 0.0,
#          u'Greg Kinnear': 0.0,
#          u'Gregory Peck': 0.0,
#          u'Guy Pearce': 5.1298987149230735,
#          u'Haley Bennett': 0.0,
#          u'Hank Azaria': 0.0,
#          u'Harrison Ford': 0.0,
#          u'Harry Dean Stanton': 0.0,
#          u'Harvey Fierstein': 0.0,
#          u'Harvey Keitel': 0.0,
#          u'Harvey Weinstein': 2.5649493574615367,
#          u'Hayden Christensen': 2.5649493574615367,
#          u'Hayden Panettiere': 2.5649493574615367,
#          u'Hayley Atwell': 0.0,
#          u'Hayley Kiyoko': 0.0,
#          u'Heath Ledger': 2.5649493574615367,
#          u'Hedy Lamarr': 0.0,
#          u'Henry Cavill': 2.5649493574615367,
#          u'Henry Winkler': 2.5649493574615367,
#          u'Hiroyuki Sanada': 10.259797429846147,
#          u'Hrithik Roshan': 5.1298987149230735,
#          u'Hugh Jackman': 5.1298987149230735,
#          u'Humphrey Bogart': 0.0,
#          u'Ian Holm': 0.0,
#          u'Ian Somerhalder': 0.0,
#          u'Indira Varma': 0.0,
#          u'Ioan Gruffudd': 0.0,
#          u'Isaiah Washington': 0.0,
#          u'Ivan Reitman': 2.5649493574615367,
#          u'Izabella Scorupco': 2.5649493574615367,
#          u'Jacinda Barrett': 0.0,
#          u'Jack Black': 0.0,
#          u'Jack Huston': 0.0,
#          u'Jack Nicholson': 0.0,
#          u'Jackie Chan': 17.954645502230758,
#          u'Jacqueline Bisset': 0.0,
#          u'Jai Courtney': 5.1298987149230735,
#          u'Jake Busey': 0.0,
#          u'Jake Gyllenhaal': 0.0,
#          u'James Arness': 2.5649493574615367,
#          u'James Callis': 0.0,
#          u'James Cameron': 5.1298987149230735,
#          u'James Coburn': 2.5649493574615367,
#          u'James Cosmo': 2.5649493574615367,
#          u'James Franco': 2.5649493574615367,
#          u'James Gandolfini': 0.0,
#          u'James Gunn': 0.0,
#          u'James Mangold': 2.5649493574615367,
#          u'James Marsden': 0.0,
#          u'James McAvoy': 5.1298987149230735,
#          u'James Norton': 5.1298987149230735,
#          u'James Purefoy': 0.0,
#          u'James Remar': 2.5649493574615367,
#          u'James Wan': 2.5649493574615367,
#          u'Jamie Campbell Bower': 0.0,
#          u'Jamie Chung': 0.0,
#          u'Jamie Foxx': 2.5649493574615367,
#          u'Jamie Lee Curtis': 2.5649493574615367,
#          u'Jamie Luner': 0.0,
#          u'Jan-Michael Vincent': 5.1298987149230735,
#          u'Jane Adams': 0.0,
#          u'Jane Fonda': 0.0,
#          u'Jane Lynch': 0.0,
#          u'Janeane Garofalo': 0.0,
#          u'Janet Varney': 0.0,
#          u'Janine Turner': 0.0,
#          u'Jared Harris': 2.5649493574615367,
#          u'Jared Leto': 0.0,
#          u'Jason Biggs': 2.5649493574615367,
#          u'Jason Earles': 0.0,
#          u'Jason Marsden': 0.0,
#          u'Jason Patric': 2.5649493574615367,
#          u'Jason Ritter': 0.0,
#          u'Jason Statham': 7.694848072384611,
#          u'Jay Hernandez': 0.0,
#          u'Jean Reno': 2.5649493574615367,
#          u'Jean-Claude Van Damme': 20.519594859692294,
#          u'Jeff Bridges': 2.5649493574615367,
#          u'Jeff Daniels': 0.0,
#          u'Jeff Fahey': 0.0,
#          u'Jeffrey Combs': 0.0,
#          u'Jeffrey Dean Morgan': 2.5649493574615367,
#          u'Jeffrey Donovan': 0.0,
#          u'Jenna Fischer': 0.0,
#          u'Jennette McCurdy': 5.1298987149230735,
#          u'Jennifer Beals': 0.0,
#          u'Jennifer Lopez': 0.0,
#          u'Jenny Agutter': 2.5649493574615367,
#          u'Jensen Ackles': 0.0,
#          u'Jeremy Irons': 2.5649493574615367,
#          u'Jeremy Piven': 0.0,
#          u'Jeremy Renner': 2.5649493574615367,
#          u'Jeremy Sisto': 2.5649493574615367,
#          u'Jesse Eisenberg': 0.0,
#          u'Jesse Lee Soffer': 0.0,
#          u'Jesse Williams': 2.5649493574615367,
#          u'Jessica Alba': 2.5649493574615367,
#          u'Jessica Biel': 2.5649493574615367,
#          u'Jessica Chastain': 0.0,
#          u'Jessica Parker Kennedy': 0.0,
#          u'Jet Li': 10.259797429846147,
#          u'Jill Ireland': 2.5649493574615367,
#          u'Jim Belushi': 0.0,
#          u'Jim Caviezel': 0.0,
#          u'Joan Allen': 2.5649493574615367,
#          u'Joan Crawford': 0.0,
#          u'Joan Plowright': 0.0,
#          u'Joanna Cassidy': 0.0,
#          u'Joanna Lumley': 2.5649493574615367,
#          u'Joanne Froggatt': 2.5649493574615367,
#          u'Jodi Benson': 0.0,
#          u'Jodie Comer': 0.0,
#          u'Jodie Foster': 0.0,
#          u'Joel Kinnaman': 0.0,
#          u'Joey King': 0.0,
#          u'John C. McGinley': 0.0,
#          u'John C. Reilly': 0.0,
#          u'John Carroll Lynch': 2.5649493574615367,
#          u'John Cassavetes': 0.0,
#          u'John Cena': 12.824746787307683,
#          u'John Cleese': 2.5649493574615367,
#          u'John Cusack': 2.5649493574615367,
#          u'John Hannah': 2.5649493574615367,
#          u'John Hughes': 5.1298987149230735,
#          u'John Huston': 0.0,
#          u'John Lee Hancock': 0.0,
#          u'John Leguizamo': 0.0,
#          u'John Malkovich': 2.5649493574615367,
#          u'John Rhys-Davies': 0.0,
#          u'John Travolta': 5.1298987149230735,
#          u'John Wayne': 12.824746787307683,
#          u'Johnathon Schaech': 0.0,
#          u'Johnny Depp': 0.0,
#          u'Johnny Galecki': 0.0,
#          u'Jon Gries': 0.0,
#          u'Jonathan Lipnicki': 2.5649493574615367,
#          u'Jonathan Rhys Meyers': 2.5649493574615367,
#          u'Jordan Ladd': 0.0,
#          u'Jordana Brewster': 2.5649493574615367,
#          u'Joseph Gordon-Levitt': 2.5649493574615367,
#          u'Josh Charles': 2.5649493574615367,
#          u'Josh Hartnett': 0.0,
#          u'Josh Lucas': 0.0,
#          u'Josh Peck': 0.0,
#          u'Jude Law': 0.0,
#          u'Judy Garland': 0.0,
#          u'Julia Stiles': 0.0,
#          u'Julie Benz': 2.5649493574615367,
#          u'Juliette Lewis': 0.0,
#          u'Justin Timberlake': 0.0,
#          u'Karl Urban': 2.5649493574615367,
#          u'Kate Beckinsale': 2.5649493574615367,
#          u'Katee Sackhoff': 2.5649493574615367,
#          u'Katharine Isabelle': 0.0,
#          u'Katherine Heigl': 2.5649493574615367,
#          u'Katherine Langford': 2.5649493574615367,
#          u'Katherine McNamara': 0.0,
#          u'Kathleen Quinlan': 0.0,
#          u'Kathleen Turner': 0.0,
#          u'Kathryn Bigelow': 0.0,
#          u'Kathy Baker': 0.0,
#          u'Katie Cassidy': 2.5649493574615367,
#          u'Kay Lenz': 0.0,
#          u'Kaya Scodelario': 0.0,
#          u'Keanu Reeves': 2.5649493574615367,
#          u'Keira Knightley': 2.5649493574615367,
#          u'Keke Palmer': 0.0,
#          u'Kelli Berglund': 0.0,
#          u'Kelly Carlson': 0.0,
#          u'Kelly Hu': 2.5649493574615367,
#          u'Kelly Rutherford': 0.0,
#          u'Ken Jeong': 0.0,
#          u'Kevin Spacey': 0.0,
#          u'Kiefer Sutherland': 2.5649493574615367,
#          u'Kim Cattrall': 2.5649493574615367,
#          u'Kim Richards': 0.0,
#          u'Kirsten Dunst': 2.5649493574615367,
#          u'Kristanna Loken': 2.5649493574615367,
#          u'Kristen Stewart': 0.0,
#          u'Kristin Bauer van Straten': 2.5649493574615367,
#          u'Kurt Russell': 5.1298987149230735,
#          u'Kurt Sutter': 0.0,
#          u'Kyle MacLachlan': 0.0,
#          u'Kyra Sedgwick': 0.0,
#          u'LL Cool J': 5.1298987149230735,
#          u'Lana Wachowski': 0.0,
#          u'Lance Henriksen': 0.0,
#          u'Lars von Trier': 0.0,
#          u'Leah Remini': 2.5649493574615367,
#          u'Lee Daniels': 0.0,
#          u'Lee Majors': 2.5649493574615367,
#          u'Lee Marvin': 0.0,
#          u'Lee Van Cleef': 2.5649493574615367,
#          u'Lena Olin': 2.5649493574615367,
#          u'Lennie James': 2.5649493574615367,
#          u'Leonor Varela': 0.0,
#          u'Leslie Bibb': 2.5649493574615367,
#          u'Leslie Mann': 2.5649493574615367,
#          u'Liam Hemsworth': 2.5649493574615367,
#          u'Liam Neeson': 7.694848072384611,
#          u'Lilly Wachowski': 7.694848072384611,
#          u'Linda Blair': 0.0,
#          u'Linda Hunt': 2.5649493574615367,
#          u'Lindsay Lohan': 0.0,
#          u'Lindy Booth': 0.0,
#          u'Lisa Kudrow': 0.0,
#          u'Lisa Leslie': 0.0,
#          u'Logan Lerman': 2.5649493574615367,
#          u'Lori Petty': 0.0,
#          u'Lou Diamond Phillips': 0.0,
#          u'Luc Besson': 0.0,
#          u'Lucas Till': 2.5649493574615367,
#          u'Lucy Liu': 5.1298987149230735,
#          u'Lukas Haas': 2.5649493574615367,
#          u'Luke Benward': 0.0,
#          u'Luke Bracey': 2.5649493574615367,
#          u'Luke Goss': 0.0,
#          u'Mackenzie Crook': 0.0,
#          u'Mackenzie Foy': 5.1298987149230735,
#          u'Madeleine Stowe': 2.5649493574615367,
#          u'Madeline Brewer': 0.0,
#          u'Madeline Carroll': 0.0,
#          u'Mads Mikkelsen': 0.0,
#          u'Maggie Grace': 0.0,
#          u'Maggie Gyllenhaal': 0.0,
#          u'Maggie Q': 5.1298987149230735,
#          u'Mallory Jansen': 0.0,
#          u'Manu Bennett': 0.0,
#          u'Marcia Gay Harden': 0.0,
#          u'Margot Kidder': 0.0,
#          u'Maria Bello': 0.0,
#          u'Marina Sirtis': 0.0,
#          u'Mariska Hargitay': 0.0,
#          u'Mark Consuelos': 0.0,
#          u'Mark Dacascos': 10.259797429846147,
#          u'Mark Valley': 2.5649493574615367,
#          u'Mark Wahlberg': 2.5649493574615367,
#          u'Mark-Paul Gosselaar': 2.5649493574615367,
#          u'Marlo Thomas': 0.0,
#          u'Marlon Brando': 2.5649493574615367,
#          u'Martin Henderson': 0.0,
#          u'Martin McDonagh': 0.0,
#          u'Martin Scorsese': 0.0,
#          u'Mary McDonnell': 0.0,
#          u'Mary-Kate Olsen': 0.0,
#          u'Matt Damon': 0.0,
#          u'Matt Dillon': 0.0,
#          u'Matthew Broderick': 5.1298987149230735,
#          u'Matthew Mercer': 0.0,
#          u'Matthias Schoenaerts': 0.0,
#          u'Maud Adams': 0.0,
#          u'Max Thieriot': 0.0,
#          u'Meaghan Rath': 2.5649493574615367,
#          u'Megalyn Echikunwoke': 2.5649493574615367,
#          u'Mel Gibson': 5.1298987149230735,
#          u'Melanie Lynskey': 0.0,
#          u'Melinda McGraw': 2.5649493574615367,
#          u'Melissa George': 0.0,
#          u'Melissa McBride': 0.0,
#          u'Mercedes Ruehl': 0.0,
#          u'Meryl Streep': 10.259797429846147,
#          u'Michael Angarano': 0.0,
#          u'Michael B. Jordan': 0.0,
#          u'Michael Bay': 5.1298987149230735,
#          u'Michael Biehn': 2.5649493574615367,
#          u'Michael C. Hall': 2.5649493574615367,
#          u'Michael Caine': 5.1298987149230735,
#          u'Michael Clarke Duncan': 0.0,
#          u'Michael Douglas': 5.1298987149230735,
#          u'Michael Ealy': 2.5649493574615367,
#          u'Michael Fassbender': 0.0,
#          u'Michael Gambon': 2.5649493574615367,
#          u'Michael Haneke': 0.0,
#          u'Michael J. Fox': 2.5649493574615367,
#          u'Michael Jai White': 7.694848072384611,
#          u'Michael Keaton': 2.5649493574615367,
#          u'Michael Madsen': 0.0,
#          u'Michael Pitt': 0.0,
#          u'Michael Rooker': 0.0,
#          u'Michael Rosenbaum': 0.0,
#          u'Michael Shannon': 5.1298987149230735,
#          u'Michael Sheen': 0.0,
#          u'Michael Trucco': 0.0,
#          u'Michael Vartan': 0.0,
#          u'Michelle Pfeiffer': 2.5649493574615367,
#          u'Michelle Rodriguez': 2.5649493574615367,
#          u'Michelle Ryan': 2.5649493574615367,
#          u'Michelle Yeoh': 23.08454421715383,
#          u'Mickey Rourke': 2.5649493574615367,
#          u'Miguel Ferrer': 2.5649493574615367,
#          u'Mike Judge': 0.0,
#          u'Mila Kunis': 0.0,
#          u'Milana Vayntrub': 2.5649493574615367,
#          u'Milla Jovovich': 7.694848072384611,
#          u'Mimi Kennedy': 0.0,
#          u'Minnie Driver': 0.0,
#          u'Mira Sorvino': 7.694848072384611,
#          u'Missy Peregrym': 2.5649493574615367,
#          u'Monica Keena': 0.0,
#          u'Monica Potter': 0.0,
#          u'Monica Raymund': 0.0,
#          u'Monique Ganderton': 0.0,
#          u'Morgan Freeman': 0.0,
#          u'Morris Chestnut': 7.694848072384611,
#          u'Mr. T': 2.5649493574615367,
#          u'Mykelti Williamson': 0.0,
#          u'Nadine Velazquez': 5.1298987149230735,
#          u'Nancy Allen': 2.5649493574615367,
#          u'Nastassja Kinski': 0.0,
#          u'Natalie Portman': 2.5649493574615367,
#          u'Natascha McElhone': 0.0,
#          u'Natassia Malthe': 0.0,
#          u'Nathalie Emmanuel': 0.0,
#          u'Nathan Fillion': 0.0,
#          u'Nathan Lane': 2.5649493574615367,
#          u'Nazanin Boniadi': 0.0,
#          u'Nicholas Gonzalez': 2.5649493574615367,
#          u'Nicholas Hoult': 2.5649493574615367,
#          u'Nick Cassavetes': 0.0,
#          u'Nick Frost': 2.5649493574615367,
#          u'Nick Robinson': 0.0,
#          u'Nicolas Cage': 2.5649493574615367,
#          u'Nicole Kidman': 0.0,
#          u'Niecy Nash': 0.0,
#          u'Nikolaj Coster-Waldau': 0.0,
#          u'Noah Emmerich': 2.5649493574615367,
#          u'Noah Hathaway': 2.5649493574615367,
#          u'Noah Taylor': 0.0,
#          u'Noomi Rapace': 0.0,
#          u'Noureen DeWulf': 0.0,
#          u'Odette Annable': 2.5649493574615367,
#          u'Olga Fonda': 2.5649493574615367,
#          u'Olga Kurylenko': 0.0,
#          u'Oliver Stone': 2.5649493574615367,
#          u'Olivia Thirlby': 5.1298987149230735,
#          u'Olivia Williams': 0.0,
#          u'Olivier Martinez': 2.5649493574615367,
#          u'Omari Hardwick': 0.0,
#          u'Orlando Bloom': 2.5649493574615367,
#          u'Orson Welles': 2.5649493574615367,
#          u'Oscar Isaac': 0.0,
#          u'Owain Yeoman': 5.1298987149230735,
#          u'Owen Wilson': 0.0,
#          u'Pam Grier': 7.694848072384611,
#          u'Pamela Anderson': 2.5649493574615367,
#          u'Parker Posey': 0.0,
#          u'Patrick Dempsey': 0.0,
#          u'Patrick J. Adams': 0.0,
#          u'Patrick Warburton': 2.5649493574615367,
#          u'Paul Feig': 0.0,
#          u'Paul Hogan': 0.0,
#          u'Paul Newman': 2.5649493574615367,
#          u'Paul Schrader': 0.0,
#          u'Paul Walker': 2.5649493574615367,
#          u'Paula Patton': 0.0,
#          u'Pauley Perrette': 0.0,
#          u'Paz Vega': 2.5649493574615367,
#          u'Pete Postlethwaite': 0.0,
#          u'Peter Cullen': 0.0,
#          u'Peter Dinklage': 2.5649493574615367,
#          u'Peter Facinelli': 2.5649493574615367,
#          u'Peter Farrelly': 0.0,
#          u'Peter Jackson': 0.0,
#          u'Peter Sarsgaard': 0.0,
#          u'Philip Seymour Hoffman': 0.0,
#          u'Philip Winchester': 2.5649493574615367,
#          u'Phoebe Tonkin': 0.0,
#          u'Pierce Brosnan': 2.5649493574615367,
#          u'Piper Laurie': 0.0,
#          u'Piper Perabo': 0.0,
#          u'Pom Klementieff': 0.0,
#          u'Powers Boothe': 0.0,
#          u'Quentin Tarantino': 2.5649493574615367,
#          u'Rachael Taylor': 2.5649493574615367,
#          u'Rachel Bilson': 0.0,
#          u'Rachel Nichols': 0.0,
#          u'Rami Malek': 0.0,
#          u'Raquel Welch': 0.0,
#          u'Ray Liotta': 0.0,
#          u'Ray McKinnon': 0.0,
#          u'Ray Stevenson': 2.5649493574615367,
#          u'Ray Wise': 0.0,
#          u'Regina King': 2.5649493574615367,
#          u'Reiko Aylesworth': 0.0,
#          u'Rhona Mitra': 0.0,
#          u'Richard Burton': 2.5649493574615367,
#          u'Richard Chamberlain': 2.5649493574615367,
#          u'Richard Dean Anderson': 0.0,
#          u'Richard Gere': 0.0,
#          u'Richard Kiel': 2.5649493574615367,
#          u'Richard Linklater': 0.0,
#          u'Richard Roxburgh': 0.0,
#          u'Richard Schiff': 2.5649493574615367,
#          u'Rick Yune': 2.5649493574615367,
#          u'Rihanna': 0.0,
#          u'Rik Mayall': 0.0,
#          u'Rip Torn': 0.0,
#          u'Rita Hayworth': 0.0,
#          u'Rob Cohen': 5.1298987149230735,
#          u'Rob McElhenney': 0.0,
#          u'Rob Zombie': 0.0,
#          u'Robert Carlyle': 0.0,
#          u'Robert Conrad': 2.5649493574615367,
#          u'Robert Davi': 0.0,
#          u'Robert De Niro': 0.0,
#          u'Robert Downey Jr.': 2.5649493574615367,
#          u'Robert Duncan McNeill': 0.0,
#          u'Robert Duvall': 0.0,
#          u'Robert Loggia': 2.5649493574615367,
#          u'Robert Patrick': 5.1298987149230735,
#          u'Robert Picardo': 0.0,
#          u'Robert Rodriguez': 10.259797429846147,
#          u'Robert Taylor': 0.0,
#          u'Robert Zemeckis': 2.5649493574615367,
#          u'Rod Steiger': 0.0,
#          u'Roger Moore': 0.0,
#          u'Roland Emmerich': 12.824746787307683,
#          u'Roman Polanski': 2.5649493574615367,
#          u'Romola Garai': 0.0,
#          u'Ron Howard': 5.1298987149230735,
#          u'Ron Moody': 2.5649493574615367,
#          u'Ronald Reagan': 2.5649493574615367,
#          u'Rosamund Pike': 5.1298987149230735,
#          u'Rose Byrne': 0.0,
#          u'Rosie Perez': 0.0,
#          u'Ross Butler': 0.0,
#          u'Roy Scheider': 0.0,
#          u'Ruby Rose': 2.5649493574615367,
#          u'Rupert Grint': 0.0,
#          u'Russell Brand': 0.0,
#          u'Russell Crowe': 2.5649493574615367,
#          u'Rutger Hauer': 0.0,
#          u'Ruth Wilson': 2.5649493574615367,
#          u'Ryan Gosling': 0.0,
#          u'Ryan Merriman': 0.0,
#          u'Ryan Reynolds': 0.0,
#          u'Saffron Burrows': 0.0,
#          u'Salman Khan': 0.0,
#          u'Sam Mendes': 0.0,
#          u'Sam Neill': 0.0,
#          u'Sam Raimi': 0.0,
#          u'Sam Riley': 0.0,
#          u'Sam Rockwell': 0.0,
#          u'Sam Worthington': 0.0,
#          u'Samantha Morton': 0.0,
#          u'Samuel L. Jackson': 2.5649493574615367,
#          u'Sanaa Lathan': 2.5649493574615367,
#          u'Sandra Bullock': 0.0,
#          u'Sarah Michelle Gellar': 0.0,
#          u'Sarah Paulson': 0.0,
#          u'Sarah Snook': 7.694848072384611,
#          u'Sarah Wayne Callies': 0.0,
#          u'Sarah Wright': 0.0,
#          u'Sasha Lane': 0.0,
#          u'Scarlett Johansson': 7.694848072384611,
#          u'Scott Adkins': 12.824746787307683,
#          u'Scott Eastwood': 2.5649493574615367,
#          u'Scott Glenn': 0.0,
#          u'Sean Astin': 2.5649493574615367,
#          u'Sean Connery': 2.5649493574615367,
#          u'Sean Faris': 0.0,
#          u'Sean Gunn': 2.5649493574615367,
#          u'Sean Patrick Flanery': 0.0,
#          u'Sean Penn': 2.5649493574615367,
#          u'Seann William Scott': 2.5649493574615367,
#          u'Sendhil Ramamurthy': 0.0,
#          u'Serinda Swan': 2.5649493574615367,
#          u'Shameik Moore': 2.5649493574615367,
#          u'Shane Black': 17.954645502230758,
#          u'Shane West': 2.5649493574615367,
#          u'Sharlto Copley': 0.0,
#          u'Sharni Vinson': 2.5649493574615367,
#          u'Sharon Stone': 2.5649493574615367,
#          u'Shawn Ashmore': 2.5649493574615367,
#          u'Sheryl Lee': 0.0,
#          u'Shia LaBeouf': 0.0,
#          u'Sid Haig': 2.5649493574615367,
#          u'Sienna Miller': 0.0,
#          u'Sigourney Weaver': 5.1298987149230735,
#          u'Sofia Boutella': 2.5649493574615367,
#          u'Sofia Coppola': 0.0,
#          u'Sofia Milos': 0.0,
#          u'Sondra Locke': 2.5649493574615367,
#          u'Sophie Okonedo': 2.5649493574615367,
#          u'Sophie Turner': 0.0,
#          u'Sprague Grayden': 0.0,
#          u'Stan Laurel': 2.5649493574615367,
#          u'Stana Katic': 0.0,
#          u'Stanley Kubrick': 0.0,
#          u'Stephanie Sigman': 2.5649493574615367,
#          u'Stephanie Szostak': 0.0,
#          u'Stephen Amell': 2.5649493574615367,
#          u'Stephen Baldwin': 2.5649493574615367,
#          u'Steve Buscemi': 0.0,
#          u'Steven R. McQueen': 0.0,
#          u'Steven Seagal': 17.954645502230758,
#          u'Steven Spielberg': 5.1298987149230735,
#          u'Steven Weber': 2.5649493574615367,
#          u'Suzy Amis': 0.0,
#          u'Sylvester Stallone': 17.954645502230758,
#          u'Tamara Tunie': 0.0,
#          u'Tania Raymonde': 10.259797429846147,
#          u'Tanya Roberts': 2.5649493574615367,
#          u'Taron Egerton': 0.0,
#          u'Taylor Kitsch': 2.5649493574615367,
#          u'Taylor Lautner': 0.0,
#          u'Taylor Sheridan': 0.0,
#          u'Terence Stamp': 2.5649493574615367,
#          u'Teri Hatcher': 0.0,
#          u'Terrence Malick': 0.0,
#          u'Terry Crews': 2.5649493574615367,
#          u'Terry Gilliam': 0.0,
#          u'Thomas Jane': 5.1298987149230735,
#          u'Thomas Kretschmann': 5.1298987149230735,
#          u'Thomas Lennon': 0.0,
#          u'Til Schweiger': 10.259797429846147,
#          u'Tim Allen': 5.1298987149230735,
#          u'Tim Daly': 0.0,
#          u'Tim Matheson': 0.0,
#          u'Tim Miller': 0.0,
#          u'Tim Robbins': 0.0,
#          u'Tim Roth': 2.5649493574615367,
#          u'Timothy Dalton': 2.5649493574615367,
#          u'Tobey Maguire': 0.0,
#          u'Tom Berenger': 2.5649493574615367,
#          u'Tom Cruise': 2.5649493574615367,
#          u'Tom Hanks': 0.0,
#          u'Tom Hardy': 2.5649493574615367,
#          u'Tom Sizemore': 0.0,
#          u'Tom Welling': 0.0,
#          u'Tom Wilkinson': 0.0,
#          u'Tommy Lee Jones': 0.0,
#          u'Tony Curran': 0.0,
#          u'Tony Danza': 0.0,
#          u'Tony Goldwyn': 2.5649493574615367,
#          u'Tony Jaa': 5.1298987149230735,
#          u'Tony Scott': 5.1298987149230735,
#          u'Tony Shalhoub': 0.0,
#          u'Topher Grace': 2.5649493574615367,
#          u'Tracy Spiridakos': 0.0,
#          u'Travis Fimmel': 0.0,
#          u'Tyne Daly': 0.0,
#          u'Tyrone Power': 0.0,
#          u'Vanessa Marcil': 0.0,
#          u'Vanity': 5.1298987149230735,
#          u'Vanna White': 0.0,
#          u'Verne Troyer': 0.0,
#          u'Vicky Kaushal': 0.0,
#          u'Vicky McClure': 2.5649493574615367,
#          u'Vin Diesel': 2.5649493574615367,
#          u'Vince Gilligan': 2.5649493574615367,
#          u'Vincent Cassel': 0.0,
#          u'Vinessa Shaw': 0.0,
#          u'Walton Goggins': 2.5649493574615367,
#          u'Warren Beatty': 0.0,
#          u'Wendell Pierce': 0.0,
#          u'Wentworth Miller': 2.5649493574615367,
#          u'Werner Herzog': 0.0,
#          u'Wesley Snipes': 12.824746787307683,
#          u'Whoopi Goldberg': 2.5649493574615367,
#          u'Wilford Brimley': 0.0,
#          u'Will Patton': 2.5649493574615367,
#          u'Will Smith': 0.0,
#          u'William Atherton': 0.0,
#          u'William Baldwin': 0.0,
#          u'William Fichtner': 0.0,
#          u'William Hurt': 0.0,
#          u'Wilmer Valderrama': 0.0,
#          u'Wim Wenders': 2.5649493574615367,
#          u'Woody Allen': 0.0,
#          u'Yancy Butler': 0.0,
#          u'Yasmine Bleeth': 0.0,
#          u'Yvonne Strahovski': 0.0,
#          u'Zac Efron': 0.0,
#          u'Zack Snyder': 2.5649493574615367,
#          u'Zoe Kazan': 2.5649493574615367,
#          u'Zoe Lister-Jones': 0.0,
#          u'Zoe Saldana': 2.5649493574615367})
